# %%
from bs4 import BeautifulSoup
import bs4
import urllib3
import re
import requests
import time
import pandas as pd
from pandas import Series, DataFrame
import html
from light_progress.commandline import ProgressBar

# %%
from xml.sax.saxutils import unescape

# %%
url = "https://suumo.jp/jj/chintai/ichiran/FR301FC001/?ar=030&bs=040&ta=13&sc=13109&cb=0.0&ct=9999999&et=9999999&cn=9999999&mb=0&mt=9999999&shkr1=03&shkr2=03&shkr3=03&shkr4=03&fw2=&srch_navi=1"

# %%
result = requests.get(url)
c = result.content

# %%
soup = BeautifulSoup(c)

# %%
summary = soup.find("div",{"id": "js-bukkenList"})
body = soup.find("body")
pages = body.find_all("div",{"class": "pagination pagination_set-nav"})
pages_text = str(pages)
pages_split = pages_text.split('</a></li>\n</ol>')
pages_numbers = int(pages_split[0][-3:].replace('>',''))

# %%
urls = []
urls.append(url)

# %%
for i in range(0,pages_numbers):
    pg = str(i+2)
    url_page = url + "&page=" + pg
    urls.append(unescape(url_page))

# %%
names, addresses, locations0, locations1, locations2, ages, heights, floors, rent, admin, others, floor_plans, areas, detail_urls = ([],)*14

# %%
cats = [names, addresses, locations0, locations1, locations2, ages, heights, floors, rent, admin, others, floor_plans, areas, detail_urls]

# %%
for url in urls:
    soup = BeautifulSoup(requests.get(url).content)
    summary = soup.find("div",{"id": "js-bukkenList"})
    apartments = summary.find_all("div",{"class":"cassetteitem"})

    url_progress = ProgressBar(len(urls))
    apartment_progress = ProgressBar(len(apartments))
    url_progress.start()
    apartment_progress.start()
    
    for apartment in apartments:
        room_number = len(apartment.find_all("tbody"))
        name = apartment.find('div', class_='cassetteitem_content-title').text
        address = apartment.find("li", class_="cassetteitem_detail-col1").text
        
        for i in range(room_number):
            names.append(name)
            addresses.append(address)
            
        sublocation = apartment.find("li", class_="cassetteitem_detail-col2")
        cols = sublocation.find_all("div")
        
        for i in range(len(cols)):
            text = cols[i].find(text=True)
            for j in range(room_number):
                if i == 1 or i == 2 or i == 0:
                    locals()["locations"+str(i)].append(text)
        
        age_and_height = apartment.find("li", class_="cassetteitem_detail-col3")
        age = age_and_height("div")[0].text
        height = age_and_height("div")[1].text
        
        for i in range(room_number):
            ages.append(age)
            heights.append(height)
            
        table = apartment.find("table")
        rows = []
        rows.append(table.find_all("tr"))
        
        data = []
        
        for row in rows:
            for tr in row:
                cols = tr.find_all("td")
                
                if len(cols) != 0:
                    _floor = cols[2].text
                    _floor = re.sub('[\r\n\t]', '', _floor)

                    _rent_cell = cols[3].find('ul').find_all('li')
                    _rent = _rent_cell[0].find('span').text
                    _admin = _rent_cell[1].find('span').text

                    _deposit_cell = cols[4].find('ul').find_all('li')
                    _deposit = _deposit_cell[0].find('span').text
                    _reikin = _deposit_cell[1].find('span').text
                    _others = _deposit + '/' + _reikin

                    _floor_cell = cols[5].find('ul').find_all('li')
                    _floor_plan = _floor_cell[0].find('span').text
                    _area = _floor_cell[1].find('span').text

                    _detail_url = cols[8].find('a')['href']
                    _detail_url = 'https://suumo.jp' + _detail_url

                    text = [_floor, _rent, _admin, _others, _floor_plan, _area, _detail_url]
                    data.append(text)

        for row in data:
            floors.append(row[0])
            rent.append(row[1])
            admin.append(row[2])
            others.append(row[3])
            floor_plans.append(row[4])
            areas.append(row[5])
            detail_urls.append(row[6])
            
        time.sleep(3)
        
        apartment_progress.forward()
    
    apartment_progress.finish()
    url_progress.forward()
    
url_progress.finish()
# Out:
# [███████████████████████████████] 100% 30/30 2020-04-20 22:11:54.469140 - 2020-04-20 22:13:24.777864
# [███████████████████████████████] 100% 30/30 2020-04-20 22:13:33.117375 - 2020-04-20 22:15:03.415558
# [▉..............................] 0% 0/30 2020-04-20 22:15:11.599744 -
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-57-23d790803db7> in <module>
#      77             detail_urls.append(row[6])
#      78
# ---> 79         time.sleep(3)
#      80
#      81         apartment_progress.forward()
#
# KeyboardInterrupt:

# %%
for cat in cats:
     cat = Series(cat)

names = Series(names)
addresses = Series(addresses)
locations0 = Series(locations0)
locations1 = Series(locations1)
locations2 = Series(locations2)
ages = Series(ages)
heights = Series(heights)
floors = Series(floors)
rent = Series(rent)
admin = Series(admin)
others = Series(others)
floor_plans = Series(floor_plans)
areas = Series(areas)
detail_urls = Series(detail_urls)
# Out:
# /Users/inori/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-c2576237c913> in <module>
#       1 for cat in cats:
# ----> 2     locals()[cat] = Series(cat)
#       3
#       4 names = Series(names)
#       5 addresses = Series(addresses)
#
# TypeError: unhashable type: 'list'

# %%
df = pd.concat([names, addresses, locations0, locations1, locations2, ages, heights, floors, rent, admin, others, floor_plans, areas, detail_urls], axis=1)

df.columns=['マンション名','住所','立地1','立地2','立地3','築年数','建物の高さ','階層','賃料料','管理費', '敷/礼/保証/敷引,償却','間取り','専有面積', '詳細URL']
# Out:
#                        マンション名           住所                  立地1  \
# 0                 ブランズシティ品川勝島    東京都品川区勝島１  東京モノレール/大井競馬場前駅 歩8分
# 1                 ブランズシティ品川勝島    東京都品川区勝島１  東京モノレール/大井競馬場前駅 歩8分
# 2               レジディアタワー目黒不動前  東京都品川区西五反田３       ＪＲ山手線/五反田駅 歩7分
# 3               レジディアタワー目黒不動前  東京都品川区西五反田３       ＪＲ山手線/五反田駅 歩7分
# 4               レジディアタワー目黒不動前  東京都品川区西五反田３       ＪＲ山手線/五反田駅 歩7分
# ..                        ...          ...                  ...
# 302  ＪＲ山手線 大崎駅 地下3地上30階建 築14年  東京都品川区西五反田３       ＪＲ山手線/大崎駅 歩15分
# 303  ＪＲ山手線 大崎駅 地下3地上30階建 築14年  東京都品川区西五反田３       ＪＲ山手線/大崎駅 歩15分
# 304  ＪＲ山手線 大崎駅 地下3地上30階建 築14年  東京都品川区西五反田３       ＪＲ山手線/大崎駅 歩15分
# 305  ＪＲ山手線 大崎駅 地下3地上30階建 築14年  東京都品川区西五反田３       ＪＲ山手線/大崎駅 歩15分
# 306  ＪＲ山手線 大崎駅 地下3地上30階建 築14年  東京都品川区西五反田３       ＪＲ山手線/大崎駅 歩15分
#
#                 立地2                  立地3   築年数      建物の高さ   階層     賃料料  \
# 0     京急本線/鮫洲駅 歩11分  りんかい線/品川シーサイド駅 歩14分   築5年  地下1地上18階建  13階    19万円
# 1     京急本線/鮫洲駅 歩11分  りんかい線/品川シーサイド駅 歩14分   築5年  地下1地上18階建  13階    19万円
# 2    東急目黒線/不動前駅 歩7分       ＪＲ山手線/目黒駅 歩14分  築14年  地下3地上30階建  12階  16.9万円
# 3    東急目黒線/不動前駅 歩7分       ＪＲ山手線/目黒駅 歩14分  築14年  地下3地上30階建   6階  16.3万円
# 4    東急目黒線/不動前駅 歩7分       ＪＲ山手線/目黒駅 歩14分  築14年  地下3地上30階建  12階  16.9万円
# ..              ...                  ...   ...        ...  ...     ...
# 302  ＪＲ山手線/五反田駅 歩7分       ＪＲ山手線/目黒駅 歩14分  築14年  地下3地上30階建  25階  33.9万円
# 303  ＪＲ山手線/五反田駅 歩7分       ＪＲ山手線/目黒駅 歩14分  築14年  地下3地上30階建  20階  34.3万円
# 304  ＪＲ山手線/五反田駅 歩7分       ＪＲ山手線/目黒駅 歩14分  築14年  地下3地上30階建  25階  34.7万円
# 305  ＪＲ山手線/五反田駅 歩7分       ＪＲ山手線/目黒駅 歩14分  築14年  地下3地上30階建  29階    36万円
# 306  ＪＲ山手線/五反田駅 歩7分       ＪＲ山手線/目黒駅 歩14分  築14年  地下3地上30階建  21階  36.3万円
#
#         管理費   敷/礼/保証/敷引,償却    間取り     専有面積  \
# 0    10000円      19万円/19万円   3LDK  71.01m2
# 1    10000円      19万円/19万円   3LDK  71.01m2
# 2         -  33.8万円/16.9万円   1LDK  37.51m2
# 3    15000円       16.3万円/-   1LDK  37.51m2
# 4    15000円  16.9万円/16.9万円   1LDK  37.51m2
# ..      ...            ...    ...      ...
# 302  15000円  67.8万円/33.9万円  2SLDK   79.9m2
# 303  15000円  68.6万円/34.3万円   3LDK     80m2
# 304  15000円       69.4万円/-   3LDK  76.92m2
# 305  15000円         72万円/-   3LDK  81.31m2
# 306  15000円       72.6万円/-   2LDK     80m2
#
#                                                  詳細URL
# 0    https://suumo.jp/chintai/jnc_000024233193/?bc=...
# 1    https://suumo.jp/chintai/jnc_000042826203/?bc=...
# 2    https://suumo.jp/chintai/jnc_000057189618/?bc=...
# 3    https://suumo.jp/chintai/jnc_000056368998/?bc=...
# 4    https://suumo.jp/chintai/jnc_000056876465/?bc=...
# ..                                                 ...
# 302  https://suumo.jp/chintai/jnc_000056876471/?bc=...
# 303  https://suumo.jp/chintai/jnc_000056362317/?bc=...
# 304  https://suumo.jp/chintai/jnc_000056876478/?bc=...
# 305  https://suumo.jp/chintai/jnc_000056008531/?bc=...
# 306  https://suumo.jp/chintai/jnc_000057144595/?bc=...
#
# [307 rows x 14 columns]
